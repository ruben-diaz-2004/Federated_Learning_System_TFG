# %%
# this notebook copy a folder in the virtual machine to the google drive
# If working with VS-Code you can upload a folder to the content folder of the virtual machine
# using the colab extension!
source_folder='/content/notebooks'
destionation_folder='.content/drive/MyDrive/investigacion/tfg_ruben/src'

# %%
from google.colab import drive
drive.mount('/content/drive')
